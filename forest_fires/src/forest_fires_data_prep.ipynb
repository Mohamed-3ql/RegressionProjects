# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# <h1>data acquisition and cleaning</h1>

# %%
# load project libraries
import numpy as np
import pandas as pd

# %%
# load data into dataframe to easy access and manipulation
forest_fire_df = pd.read_csv('forestfires.csv')
# display the first five rows in dataframe
forest_fire_df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
# dataset description 
desc = open('forestfires.names','r')
desc = str(desc.readlines())
desc = eval(desc)

# %%
# finding missing values
forest_fire_df.replace("None",np.nan,inplace = True)

# %%
missing_data = forest_fire_df.isnull()

# %%
missing_data.head()
# Out:
#        X      Y  month    day   FFMC    DMC     DC    ISI   temp     RH  \
# 0  False  False  False  False  False  False  False  False  False  False
# 1  False  False  False  False  False  False  False  False  False  False
# 2  False  False  False  False  False  False  False  False  False  False
# 3  False  False  False  False  False  False  False  False  False  False
# 4  False  False  False  False  False  False  False  False  False  False
#
#     wind   rain   area
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False

# %%
# counting missing values
for col in mis.columns.values.tolist():
    print(col)
    print(forest_fire_df[col].value_counts())
    print("")
# Out:
# X
# 4    91
# 6    86
# 2    73
# 8    61
# 7    60
# 3    55
# 1    48
# 5    30
# 9    13
# Name: X, dtype: int64
#
# Y
# 4    203
# 5    125
# 6     74
# 3     64
# 2     44
# 9      6
# 8      1
# Name: Y, dtype: int64
#
# month
# aug    184
# sep    172
# mar     54
# jul     32
# feb     20
# jun     17
# oct     15
# apr      9
# dec      9
# may      2
# jan      2
# nov      1
# Name: month, dtype: int64
#
# day
# sun    95
# fri    85
# sat    84
# mon    74
# tue    64
# thu    61
# wed    54
# Name: day, dtype: int64
#
# FFMC
# 91.6    28
# 92.1    28
# 91.0    22
# 91.7    19
# 93.7    16
# 92.4    16
# 92.5    15
# 94.8    14
# 90.2    12
# 90.1    12
# 92.9    12
# 91.4    11
# 91.2    11
# 93.5    11
# 91.1    10
# 94.3     9
# 90.9     9
# 92.2     9
# 91.5     9
# 91.8     9
# 90.6     8
# 95.2     7
# 93.1     7
# 93.4     6
# 96.1     6
# 92.3     6
# 92.8     6
# 90.3     6
# 91.9     6
# 90.7     5
#         ..
# 83.9     2
# 88.9     1
# 69.0     1
# ...
